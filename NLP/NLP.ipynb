# %%
from pathlib import Path
from textblob import TextBlob
blob = TextBlob(Path('Romeo Juliet.txt').read_text())

# %%
blob.word_counts['juliet']
# Out:
# 194

# %%
blob.word_counts['romeo']
# Out:
# 319

# %%
from textblob import TextBlob
from nltk.corpus import stopwords
stops = stopwords.words('english')
blob = TextBlob('Today is a beautiful day.')
[word for word in blob.words if word not in stops]
# Out:
# ['Today', 'beautiful', 'day']

# %%
from textblob import TextBlob
text = 'Today is a beautiful day. Tommorow looks like bad weather'
blob = TextBlob(text)
blob.ngrams(5)
# Out:
# [WordList(['Today', 'is', 'a', 'beautiful', 'day']),
#  WordList(['is', 'a', 'beautiful', 'day', 'Tommorow']),
#  WordList(['a', 'beautiful', 'day', 'Tommorow', 'looks']),
#  WordList(['beautiful', 'day', 'Tommorow', 'looks', 'like']),
#  WordList(['day', 'Tommorow', 'looks', 'like', 'bad']),
#  WordList(['Tommorow', 'looks', 'like', 'bad', 'weather'])]

# %%
from pathlib import Path
from textblob import TextBlob
blob = TextBlob(Path('Romeo Juliet.txt').read_text())
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
items = blob.word_counts.items()
items = [item for item in items if item[0] not in stop_words]
from operator import itemgetter
sorted_items = sorted(items, key=lambda x: x[1], reverse=True)
top20 = sorted_items[1:21]
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
df = pd.DataFrame(top20, columns=['word', 'count'])
colors = mpl.rcParams['axes.prop_cycle'].by_key()['color']
axes = df.plot.bar(x='word', y='count', legend=False, color=colors)
plt.gcf().tight_layout()

# %%
from pathlib import Path
from textblob import TextBlob
blob = TextBlob(Path('Romeo Juliet.txt').read_text())
text = blob.raw
import imageio
import imageio.v2 as imageio
mask_image = imageio.imread('mask_heart.jpeg')
from wordcloud import WordCloud
wordcloud = WordCloud(colormap = 'prism', mask = mask_image, background_color = 'white')
wordcloud = wordcloud.generate(text)
wordcloud = wordcloud.to_file('RomeoAndJulietHeart.jpeg')
get_ipython().run_line_magic('matplotlib', '')
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
import spacy
nlp = spacy.load('en')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[25], line 2
#       1 import spacy
# ----> 2 nlp = spacy.load('en')
#
# File ~/anaconda3/lib/python3.13/site-packages/spacy/__init__.py:74, in load(name, vocab, disable, enable, exclude, config)
#      50 def load(
#      51     name: Union[str, Path],
#      52     *,
#    (...)
#      57     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      58 ) -> Language:
#      59     """Load a spaCy model from an installed package or a local path.
#      60
#      61     name (str): Package name or model path.
#    (...)
#      72     RETURNS (Language): The loaded nlp object.
#      73     """
# ---> 74     return util.load_model(
#      75         name,
#      76         vocab=vocab,
#      77         disable=disable,
#      78         enable=enable,
#      79         exclude=exclude,
# ...
